# %%
import test
# Out:
# [[-3.00538166 -1.70119086  1.        ]
#  [-2.90810539 -1.69958926  1.        ]
#  [-2.95895365 -1.66093956  1.        ]
#  ...
#  [ 2.86326783  1.54320346  1.        ]
#  [ 2.92932367  1.62139327  1.        ]
#  [ 2.98866573  1.57751153  1.        ]]
# >epoch=0, lrate=0.300, error=427.507
# >epoch=1, lrate=0.300, error=606.100
# >epoch=2, lrate=0.300, error=709.456
# >epoch=3, lrate=0.300, error=541.485
# >epoch=4, lrate=0.300, error=1019.727
# >epoch=5, lrate=0.300, error=601.209
# >epoch=6, lrate=0.300, error=708.277
# >epoch=7, lrate=0.300, error=521.514
# >epoch=8, lrate=0.300, error=1128.057
# >epoch=9, lrate=0.300, error=601.882
# >epoch=10, lrate=0.300, error=708.800
# >epoch=11, lrate=0.300, error=528.168
# >epoch=12, lrate=0.300, error=1098.548
# >epoch=13, lrate=0.300, error=594.647
# >epoch=14, lrate=0.300, error=687.426
# >epoch=15, lrate=0.300, error=702.649
# >epoch=16, lrate=0.300, error=688.811
# >epoch=17, lrate=0.300, error=687.469
# >epoch=18, lrate=0.300, error=691.695
# >epoch=19, lrate=0.300, error=673.157
# >epoch=20, lrate=0.300, error=708.933
# >epoch=21, lrate=0.300, error=545.173
# >epoch=22, lrate=0.300, error=1003.984
# >epoch=23, lrate=0.300, error=597.425
# >epoch=24, lrate=0.300, error=700.939
# >epoch=25, lrate=0.300, error=697.867
# >epoch=26, lrate=0.300, error=516.923
# >epoch=27, lrate=0.300, error=1230.897
# >epoch=28, lrate=0.300, error=602.909
# >epoch=29, lrate=0.300, error=709.276
# >epoch=30, lrate=0.300, error=537.180
# >epoch=31, lrate=0.300, error=1021.791
# >epoch=32, lrate=0.300, error=599.106
# >epoch=33, lrate=0.300, error=705.411
# >epoch=34, lrate=0.300, error=594.931
# >epoch=35, lrate=0.300, error=898.305
# >epoch=36, lrate=0.300, error=700.916
# >epoch=37, lrate=0.300, error=516.736
# >epoch=38, lrate=0.300, error=1074.563
# >epoch=39, lrate=0.300, error=786.361
# >epoch=40, lrate=0.300, error=523.938
# >epoch=41, lrate=0.300, error=1124.978
# >epoch=42, lrate=0.300, error=602.386
# >epoch=43, lrate=0.300, error=709.082
# >epoch=44, lrate=0.300, error=533.219
# >epoch=45, lrate=0.300, error=1003.588
# >epoch=46, lrate=0.300, error=669.359
# >epoch=47, lrate=0.300, error=709.378
# >epoch=48, lrate=0.300, error=540.509
# >epoch=49, lrate=0.300, error=1021.238
# >epoch=50, lrate=0.300, error=601.154
# >epoch=51, lrate=0.300, error=708.227
# >epoch=52, lrate=0.300, error=521.041
# >epoch=53, lrate=0.300, error=1128.096
# >epoch=54, lrate=0.300, error=601.623
# >epoch=55, lrate=0.300, error=708.619
# >epoch=56, lrate=0.300, error=525.438
# >epoch=57, lrate=0.300, error=1120.631
# >epoch=58, lrate=0.300, error=601.926
# >epoch=59, lrate=0.300, error=708.826
# >epoch=60, lrate=0.300, error=528.599
# >epoch=61, lrate=0.300, error=1088.272
# >epoch=62, lrate=0.300, error=583.617
# >epoch=63, lrate=0.300, error=809.819
# >epoch=64, lrate=0.300, error=590.554
# >epoch=65, lrate=0.300, error=617.335
# >epoch=66, lrate=0.300, error=1121.053
# >epoch=67, lrate=0.300, error=601.988
# >epoch=68, lrate=0.300, error=708.865
# >epoch=69, lrate=0.300, error=529.261
# >epoch=70, lrate=0.300, error=1039.991
# >epoch=71, lrate=0.300, error=707.139
# >epoch=72, lrate=0.300, error=515.348
# >epoch=73, lrate=0.300, error=1216.154
# >epoch=74, lrate=0.300, error=600.416
# >epoch=75, lrate=0.300, error=707.397
# >epoch=76, lrate=0.300, error=515.895
# >epoch=77, lrate=0.300, error=1139.340
# >epoch=78, lrate=0.300, error=705.502
# >epoch=79, lrate=0.300, error=562.443
# >epoch=80, lrate=0.300, error=1109.991
# >epoch=81, lrate=0.300, error=599.786
# >epoch=82, lrate=0.300, error=706.576
# >epoch=83, lrate=0.300, error=516.767
# >epoch=84, lrate=0.300, error=1230.660
# >epoch=85, lrate=0.300, error=602.888
# >epoch=86, lrate=0.300, error=709.270
# >epoch=87, lrate=0.300, error=537.034
# >epoch=88, lrate=0.300, error=1021.617
# >epoch=89, lrate=0.300, error=598.881
# >epoch=90, lrate=0.300, error=704.922
# >epoch=91, lrate=0.300, error=649.186
# >epoch=92, lrate=0.300, error=617.201
# >epoch=93, lrate=0.300, error=1122.493
# >epoch=94, lrate=0.300, error=602.178
# >epoch=95, lrate=0.300, error=708.976
# >epoch=96, lrate=0.300, error=531.227
# >epoch=97, lrate=0.300, error=960.120
# >epoch=98, lrate=0.300, error=811.759
# >epoch=99, lrate=0.300, error=580.965
# [0.7786057594550677, 2.6477801353591266, -0.9541866250167582]
# Expected=1.000, Predicted=0.004 [0]
# Expected=1.000, Predicted=0.005 [0]
# Expected=1.000, Predicted=0.006 [0]
# Expected=1.000, Predicted=0.009 [0]
# Expected=1.000, Predicted=0.010 [0]
# Expected=1.000, Predicted=0.012 [0]
# Expected=1.000, Predicted=0.016 [0]
# Expected=1.000, Predicted=0.028 [0]
# Expected=1.000, Predicted=0.036 [0]
# Expected=1.000, Predicted=0.035 [0]
# Expected=1.000, Predicted=0.041 [0]
# Expected=1.000, Predicted=0.065 [0]
# Expected=1.000, Predicted=0.076 [0]
# Expected=1.000, Predicted=0.079 [0]
# Expected=1.000, Predicted=0.107 [0]
# Expected=0.000, Predicted=0.181 [0]
# Expected=0.000, Predicted=0.224 [0]
# Expected=0.000, Predicted=0.283 [0]
# Expected=0.000, Predicted=0.338 [0]
# Expected=0.000, Predicted=0.328 [0]
# Expected=0.000, Predicted=0.425 [0]
# Expected=0.000, Predicted=0.548 [1]
# Expected=0.000, Predicted=0.607 [1]
# Expected=0.000, Predicted=0.585 [1]
# Expected=0.000, Predicted=0.718 [1]
# Expected=0.000, Predicted=0.697 [1]
# Expected=0.000, Predicted=0.784 [1]
# Expected=0.000, Predicted=0.825 [1]
# Expected=0.000, Predicted=0.866 [1]
# Expected=0.000, Predicted=0.888 [1]
# Expected=0.000, Predicted=0.899 [1]
# Expected=0.000, Predicted=0.923 [1]
# Expected=0.000, Predicted=0.942 [1]
# Expected=0.000, Predicted=0.952 [1]
# Expected=0.000, Predicted=0.961 [1]
# Expected=0.000, Predicted=0.973 [1]
# Expected=0.000, Predicted=0.984 [1]
# Expected=0.000, Predicted=0.987 [1]
# Expected=0.000, Predicted=0.987 [1]
# Expected=0.000, Predicted=0.991 [1]
# Expected=0.000, Predicted=0.995 [1]
# Expected=0.000, Predicted=0.994 [1]
# Expected=1.000, Predicted=0.996 [1]
# Expected=1.000, Predicted=0.997 [1]
# Expected=1.000, Predicted=0.998 [1]
# Expected=1.000, Predicted=0.998 [1]
# Expected=1.000, Predicted=0.999 [1]
# Expected=1.000, Predicted=0.999 [1]
# Expected=1.000, Predicted=0.999 [1]
# Expected=1.000, Predicted=0.999 [1]
# Expected=1.000, Predicted=0.999 [1]
# Expected=1.000, Predicted=1.000 [1]
# Expected=1.000, Predicted=1.000 [1]
# Expected=1.000, Predicted=1.000 [1]
# Expected=1.000, Predicted=1.000 [1]
# Expected=1.000, Predicted=1.000 [1]
# Expected=1.000, Predicted=1.000 [1]
# Expected=1.000, Predicted=1.000 [1]
# Expected=1.000, Predicted=1.000 [1]
# Expected=1.000, Predicted=1.000 [1]
# 0.4

# %%
import matplotlib.pyplot as plt
import numpy as np
import train
data=np.array(train.data)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Key: Dark=0 Light=1')
plt.scatter(data[:,0],data[:,1],c=data[:,2])
plt.show()
